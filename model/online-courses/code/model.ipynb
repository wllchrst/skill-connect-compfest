# %% [markdown]
# ### Content-Based Filtering for Course Recommendation using TF-IDF Vectorization and Cosine Similarity

# %%
import pandas as pd

# %%
data = pd.read_csv('../dataset/final_courses_data.csv')

# %%
data
# Out:
#                                                   title  \
# 0     (ISC)² Systems Security Certified Practitioner...
# 1                              .NET FullStack Developer
# 2     21st Century Energy Transition: how do we make...
# 3     A Crash Course in Causality:  Inferring Causal...
# 4              AI Applications in Marketing and Finance
# ...                                                 ...
# 5931  Game Theory Algorithms in Competitive Programm...
# 5932  Siemens WinCC SCADA Programming, SCADA1 ( Basic )
# 5933  Python Object Oriented Programming (OOP): Begi...
# 5934                                jQuery Basics Guide
# 5935  Introduction to Android Development for beginners
#
#                                             description  level rating  \
# 0     Pursue better IT security job opportunities an...      0    4.7
# 1     Develop the proficiency required to design and...      1    4.3
# 2     Affordable, abundant and reliable energy is fu...      0    4.8
# 3     We have all heard the phrase “correlation does...      1    4.7
# 4     In this course, you will learn about AI-powere...      3    4.7
# ...                                                 ...    ...    ...
# 5931  Dive deep into game theory algorithms, learn &...      3      -
# 5932  This course is a great push for any one who wa...      2      -
# 5933         Deep OOP Foundations From Absolute Scratch      3      -
# 5934  Everything you need to know to Build a Retirem...      0      -
# 5935    Create an Android App step by step from scratch      0      -
#
#       reviews_num                                               link  \
# 0           492.0  https://www.coursera.org/specializations/sscp-...
# 1            51.0  https://www.coursera.org/specializations/dot-n...
# 2            62.0  https://www.coursera.org/learn/21st-century-en...
# 3           517.0  https://www.coursera.org/learn/crash-course-in...
# 4           140.0  https://www.coursera.org/learn/wharton-ai-appl...
# ...           ...                                                ...
# 5931  124 reviews  https://www.udemy.com/course/game-theory-algor...
# 5932  124 reviews  https://www.udemy.com/course/siemens-wincc-scada/
# 5933  124 reviews  https://www.udemy.com/course/object-oriented-p...
# 5934  124 reviews   https://www.udemy.com/course/learn-basic-jquery/
# 5935  124 reviews  https://www.udemy.com/course/introduction-to-a...
#
#                                                   image  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 5931  https://img-b.udemycdn.com/course/240x135/3878...
# 5932  https://img-b.udemycdn.com/course/240x135/2858...
# 5933  https://img-b.udemycdn.com/course/240x135/4450...
# 5934  https://img-b.udemycdn.com/course/240x135/2554...
# 5935  https://img-b.udemycdn.com/course/240x135/1389...
#
#                                       combined_features
# 0     (ISC)² Systems Security Certified Practitioner...
# 1     .NET FullStack Developer Develop the proficien...
# 2     21st Century Energy Transition: how do we make...
# 3     A Crash Course in Causality:  Inferring Causal...
# 4     AI Applications in Marketing and Finance In th...
# ...                                                 ...
# 5931  Game Theory Algorithms in Competitive Programm...
# 5932  Siemens WinCC SCADA Programming, SCADA1 ( Basi...
# 5933  Python Object Oriented Programming (OOP): Begi...
# 5934  jQuery Basics Guide Everything you need to kno...
# 5935  Introduction to Android Development for beginn...
#
# [5936 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(data['combined_features'])

# %%
# def recommend_items(item_title, data, tfidf_matrix):
#     if item_title not in data['title'].values:
#         return f"Item '{item_title}' tidak ditemukan dalam dataset."
#     # index dr item yg diminta
#     idx = data.index[data['title'] == item_title].tolist()[0]
#     # itung cosine similarity antara item yg diminta sm semua item yg lain
#     cosine_sim = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
#     # index dr item yg paling mirip
#     similar_indices = cosine_sim.argsort()[:-6:-1]
#     similar_indices = similar_indices[similar_indices != idx]
#     # judul item yg direkomendasiin
#     recommendations = data.iloc[similar_indices]['title'].tolist()
#     return recommendations

# %%
def recommend_search_items(item, vectorizer, tfidf_matrix, data):
    if item not in data['title'].values:
        print("There is no course with that name.")
    print(f"Here are some recommendations for '{item}':")
    # vectorize item
    item_vec = vectorizer.transform([item])
    # compute similarity scores
    cosine_sim = cosine_similarity(item_vec, tfidf_matrix).flatten()
    # rank results
    ranked_indices = cosine_sim.argsort()[:-6:-1]
    # retrieve results
    search_results = data.iloc[ranked_indices]['title'].tolist()
    return search_results

# %%
# recommendation and search testing

# item_to_test = 'Introduction to Machine Learning'
# recommended_items = recommend_items(item_to_test, data, tfidf_matrix)
# print(f"Rekomendasi untuk '{item_to_test}': {recommended_items}")

test = input("input item name:")
print('Item Name:', test)
print()
search_results = recommend_search_items(test, vectorizer, tfidf_matrix, data)
print(search_results)
# Out:
# Item Name: introduction to machine learning
#
# There is no course with that name.
# Here are some recommendations for 'introduction to machine learning':
# ['Machine Learning In The Cloud With Azure Machine Learning', 'Machine Learning Guide: Learn Machine Learning Algorithms', "Machine Learning : A Beginner's Basic Introduction", '2022 Machine Learning A to Z : 5 Machine Learning Projects', 'Practical Introduction to Machine Learning with Python']

# %%
import pickle

data.to_pickle('../pickle/courses_data.pkl')

with open('../pickle/vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

with open('../pickle/tfidf_matrix.pkl', 'wb') as f:
    pickle.dump(tfidf_matrix, f)
